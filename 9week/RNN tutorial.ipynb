# %%
import numpy as np

# %% [markdown]
# # 0. hyperparameter 상수화
#
# #### hyperparamter 자주 바꾸게 되므로 python에는 상수라는 개념이 없지만 C처럼 맨 위에 상수처럼 선언하고 진행
#
# #### (다른 kernel들을 보면 대문자로 맨 위에서 선언하고 진행하는 경우가 많습니다.)
#
# max_features = 사용할 단어의 최대 개수
#
# max_len = 문장의 최대 길이
#
# embedding_dims = 단어 vector 내부의 원소 개수

# %%
max_features = 20000

max_len = 200 # time_step
embedding_dims = 50 # feature

# %% [markdown]
# -----------

# %% [markdown]
# # 1. data upload

# %%
from tensorflow.keras.datasets import imdb

# %% [markdown]
# ## 1) data upload

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
# Out:
# <__array_function__ internals>:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\datasets\imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\keras\datasets\imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %% [markdown]
# ## 2) data에 대한 파악 - X

# %%
x_train.shape
# Out:
# (25000,)

# %%
print('train data가 ' + str(len(x_train)) +'개')
# Out:
# train data가 25000개

# %% [markdown]
# text
#
# 딥러닝 모델은 숫자를 받습니다.
#
# text -> index ->(embedding) -> vector

# %% [markdown]
# 그럼 data 내부는 어떻게 구성되어 있는가?
#
# 원래는 text(문자 data) 자체를 vector로 변환하는 작업 필요하지만 NLP를 자세히 다루는 시간이 아니기 때문에
#
# 숫자(vector) 형태의 data를 보게 됩니다.

# %%
x_train # 25000개
# Out:
# array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
#        list([1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463, 4369, 5012, 134, 26, 4, 715, 8, 118, 1634, 14, 394, 20, 13, 119, 954, 189, 102, 5, 207, 110, 3103, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2300, 1523, 5, 647, 4, 116, 9, 35, 8163, 4, 229, 9, 340, 1322, 4, 118, 9, 4, 130, 4901, 19, 4, 1002, 5, 89, 29, 952, 46, 37, 4, 455, 9, 45, 43, 38, 1543, 1905, 398, 4, 1649, 26, 6853, 5, 163, 11, 3215, 10156, 4, 1153, 9, 194, 775, 7, 8255, 11596, 349, 2637, 148, 605, 15358, 8003, 15, 123, 125, 68, 2, 6853, 15, 349, 165, 4362, 98, 5, 4, 228, 9, 43, 2, 1157, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 4373, 228, 8255, 5, 2, 656, 245, 2350, 5, 4, 9837, 131, 152, 491, 18, 2, 32, 7464, 1212, 14, 9, 6, 371, 78, 22, 625, 64, 1382, 9, 8, 168, 145, 23, 4, 1690, 15, 16, 4, 1355, 5, 28, 6, 52, 154, 462, 33, 89, 78, 285, 16, 145, 95]),
#        list([1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 5974, 54, 61, 369, 13, 71, 149, 14, 22, 112, 4, 2401, 311, 12, 16, 3711, 33, 75, 43, 1829, 296, 4, 86, 320, 35, 534, 19, 263, 4821, 1301, 4, 1873, 33, 89, 78, 12, 66, 16, 4, 360, 7, 4, 58, 316, 334, 11, 4, 1716, 43, 645, 662, 8, 257, 85, 1200, 42, 1228, 2578, 83, 68, 3912, 15, 36, 165, 1539, 278, 36, 69, 2, 780, 8, 106, 14, 6905, 1338, 18, 6, 22, 12, 215, 28, 610, 40, 6, 87, 326, 23, 2300, 21, 23, 22, 12, 272, 40, 57, 31, 11, 4, 22, 47, 6, 2307, 51, 9, 170, 23, 595, 116, 595, 1352, 13, 191, 79, 638, 89, 2, 14, 9, 8, 106, 607, 624, 35, 534, 6, 227, 7, 129, 113]),
#        ...,
#        list([1, 11, 6, 230, 245, 6401, 9, 6, 1225, 446, 2, 45, 2174, 84, 8322, 4007, 21, 4, 912, 84, 14532, 325, 725, 134, 15271, 1715, 84, 5, 36, 28, 57, 1099, 21, 8, 140, 8, 703, 5, 11656, 84, 56, 18, 1644, 14, 9, 31, 7, 4, 9406, 1209, 2295, 2, 1008, 18, 6, 20, 207, 110, 563, 12, 8, 2901, 17793, 8, 97, 6, 20, 53, 4767, 74, 4, 460, 364, 1273, 29, 270, 11, 960, 108, 45, 40, 29, 2961, 395, 11, 6, 4065, 500, 7, 14492, 89, 364, 70, 29, 140, 4, 64, 4780, 11, 4, 2678, 26, 178, 4, 529, 443, 17793, 5, 27, 710, 117, 2, 8123, 165, 47, 84, 37, 131, 818, 14, 595, 10, 10, 61, 1242, 1209, 10, 10, 288, 2260, 1702, 34, 2901, 17793, 4, 65, 496, 4, 231, 7, 790, 5, 6, 320, 234, 2766, 234, 1119, 1574, 7, 496, 4, 139, 929, 2901, 17793, 7750, 5, 4241, 18, 4, 8497, 13164, 250, 11, 1818, 7561, 4, 4217, 5408, 747, 1115, 372, 1890, 1006, 541, 9303, 7, 4, 59, 11027, 4, 3586, 2]),
#        list([1, 1446, 7079, 69, 72, 3305, 13, 610, 930, 8, 12, 582, 23, 5, 16, 484, 685, 54, 349, 11, 4120, 2959, 45, 58, 1466, 13, 197, 12, 16, 43, 23, 2, 5, 62, 30, 145, 402, 11, 4131, 51, 575, 32, 61, 369, 71, 66, 770, 12, 1054, 75, 100, 2198, 8, 4, 105, 37, 69, 147, 712, 75, 3543, 44, 257, 390, 5, 69, 263, 514, 105, 50, 286, 1814, 23, 4, 123, 13, 161, 40, 5, 421, 4, 116, 16, 897, 13, 2, 40, 319, 5872, 112, 6700, 11, 4803, 121, 25, 70, 3468, 4, 719, 3798, 13, 18, 31, 62, 40, 8, 7200, 4, 2, 7, 14, 123, 5, 942, 25, 8, 721, 12, 145, 5, 202, 12, 160, 580, 202, 12, 6, 52, 58, 11418, 92, 401, 728, 12, 39, 14, 251, 8, 15, 251, 5, 2, 12, 38, 84, 80, 124, 12, 9, 23]),
#        list([1, 17, 6, 194, 337, 7, 4, 204, 22, 45, 254, 8, 106, 14, 123, 4, 12815, 270, 14437, 5, 16923, 12255, 732, 2098, 101, 405, 39, 14, 1034, 4, 1310, 9, 115, 50, 305, 12, 47, 4, 168, 5, 235, 7, 38, 111, 699, 102, 7, 4, 4039, 9245, 9, 24, 6, 78, 1099, 17, 2345, 16553, 21, 27, 9685, 6139, 5, 2, 1603, 92, 1183, 4, 1310, 7, 4, 204, 42, 97, 90, 35, 221, 109, 29, 127, 27, 118, 8, 97, 12, 157, 21, 6789, 2, 9, 6, 66, 78, 1099, 4, 631, 1191, 5, 2642, 272, 191, 1070, 6, 7585, 8, 2197, 2, 10755, 544, 5, 383, 1271, 848, 1468, 12183, 497, 16876, 8, 1597, 8778, 19280, 21, 60, 27, 239, 9, 43, 8368, 209, 405, 10, 10, 12, 764, 40, 4, 248, 20, 12, 16, 5, 174, 1791, 72, 7, 51, 6, 1739, 22, 4, 204, 131, 9])],
#       dtype=object)

# %% [markdown]
# 25000개의 문장이 x_train에 담겨있다.
#
# 그럼 그 문장은 어떻게 생겼는가?

# %%
print(x_train[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
len(x_train[0])
# Out:
# 218

# %%
len(x_train[1])
# Out:
# 189

# %% [markdown]
# 각 문장의 길이가 다르다는 문제가 생김

# %% [markdown]
# ## 3) data에 대한 파악 - y

# %%
y_train.shape
# Out:
# (25000,)

# %%
print('역시 train data가 ' + str(len(y_train)) +'개')
# Out:
# 역시 train data가 25000개

# %% [markdown]
# 그 값은 어떻게 구성이 되어있는가?

# %%
y_train
# Out:
# array([1, 0, 0, ..., 0, 1, 0], dtype=int64)

# %% [markdown]
# 0과 1이니 왠지 binary classfication?
#
# 하지만 확인이 필요합니다.

# %%
np.unique(y_train)
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# 0과 1로만 구성이 되어있으므로 binary classification 맞습니다. (긍정 리뷰와 부정 리뷰 구분)

# %% [markdown]
# ------

# %% [markdown]
# # 2. data preprocess

# %% [markdown]
# **오늘은 다른 전처리는 생략하고 진행하겠습니다.**

# %%
print(x_train[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %% [markdown]
# 아까 문장의 길이가 각각 다르므로 진행해야하는 것은 문장의 길이를 통일하는 방법
#
# (이미지도 그렇고 전처리의 핵심 중 하나는 data의 형태를 동일하게 해주어야 합니다.)

# %% [markdown]
# --- 다시

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

# %%
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (25000, 200)
# x_test shape: (25000, 200)

# %%
x_train[0]
# Out:
# array([    5,    25,   100,    43,   838,   112,    50,   670,     2,
#            9,    35,   480,   284,     5,   150,     4,   172,   112,
#          167,     2,   336,   385,    39,     4,   172,  4536,  1111,
#           17,   546,    38,    13,   447,     4,   192,    50,    16,
#            6,   147,  2025,    19,    14,    22,     4,  1920,  4613,
#          469,     4,    22,    71,    87,    12,    16,    43,   530,
#           38,    76,    15,    13,  1247,     4,    22,    17,   515,
#           17,    12,    16,   626,    18, 19193,     5,    62,   386,
#           12,     8,   316,     8,   106,     5,     4,  2223,  5244,
#           16,   480,    66,  3785,    33,     4,   130,    12,    16,
#           38,   619,     5,    25,   124,    51,    36,   135,    48,
#           25,  1415,    33,     6,    22,    12,   215,    28,    77,
#           52,     5,    14,   407,    16,    82, 10311,     8,     4,
#          107,   117,  5952,    15,   256,     4,     2,     7,  3766,
#            5,   723,    36,    71,    43,   530,   476,    26,   400,
#          317,    46,     7,     4, 12118,  1029,    13,   104,    88,
#            4,   381,    15,   297,    98,    32,  2071,    56,    26,
#          141,     6,   194,  7486,    18,     4,   226,    22,    21,
#          134,   476,    26,   480,     5,   144,    30,  5535,    18,
#           51,    36,    28,   224,    92,    25,   104,     4,   226,
#           65,    16,    38,  1334,    88,    12,    16,   283,     5,
#           16,  4472,   113,   103,    32,    15,    16,  5345,    19,
#          178,    32])

# %% [markdown]
# ------

# %% [markdown]
# ### cf> input에 대한 이야기
#
# 현재 train_x.shape = (25000, 200)
#
# 우리가 RNN 모델에 넣어야 할 data의 ndim = 3 (25000, 200, input_dim)
#
# 즉, 단어를 vetor로 바꾸는 과정이 남았습니다.

# %% [markdown]
# ### 정리
#
# #### <font color="blue"> 1> 한 문장당 단어 = max_len(200)개
#
# (이 단어 각각을 또 vector로 만든다.)
#
# #### <font color="blue"> 2> 이 단어 각각 vector의 원소 개수 = embedding_dims(50)개
#
# (이 역할을 Embedding layer에서 진행)

# %% [markdown]
# # 3. build the model

# %% [markdown]
# simpleRNN
#
# - return_sequence = False => 2d array
# - return_sequence = True => 3d array

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, SimpleRNN

# %%
def create_model():
    model = Sequential()
    # 2d_array (data, max_len)
    model.add(Embedding(max_features, embedding_dims, input_length=max_len))
    # 3d_array (data, max_len, embedding_dims)
    model.add(SimpleRNN(32))
    # 2d_array (data, value)
    model.add(Dense(1, activation='sigmoid'))
    # 1d_array [0, 1, 0, 0, 1]
    
    model.compile(optimizer = 'adam', metrics=['accuracy'], loss = 'binary_crossentropy')

    return model

# %%
model = create_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 200, 50)           1000000
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 32)                2656
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 1,002,689
# Trainable params: 1,002,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, validation_split=0.2, epochs=5, batch_size=512)
# Out:
# Epoch 1/5
# 40/40 [==============================] - 13s 288ms/step - loss: 0.6820 - accuracy: 0.5503 - val_loss: 0.5312 - val_accuracy: 0.7428
# Epoch 2/5
# 40/40 [==============================] - 7s 163ms/step - loss: 0.4428 - accuracy: 0.8112 - val_loss: 0.3809 - val_accuracy: 0.8378
# Epoch 3/5
# 40/40 [==============================] - 8s 191ms/step - loss: 0.2570 - accuracy: 0.9086 - val_loss: 0.3276 - val_accuracy: 0.8614
# Epoch 4/5
# 40/40 [==============================] - 6s 158ms/step - loss: 0.1630 - accuracy: 0.9506 - val_loss: 0.3555 - val_accuracy: 0.8458
# Epoch 5/5
# 40/40 [==============================] - 6s 141ms/step - loss: 0.1260 - accuracy: 0.9637 - val_loss: 0.3850 - val_accuracy: 0.8460

# %% [markdown]
# ------

# %% [markdown]
# # 4. F1 score 사용
#
# ## 1) tensorflow의 metric을 사용
#
# - tensorflow가 아직도 불안정한 면이 일부 있습니다. 잘 안 되는 분들은 2) 아래 예시로 하셔도 됩니다.

# %%
# 설치가 필요한 분들은 아래 tensorflow_addons를 설치해주세요.

#!pip install tensorflow_addons

# %%
from tensorflow.keras.metrics import Precision, Recall
from tensorflow_addons.metrics import F1Score

# %%
precision = Precision()
recall = Recall()
f1score = F1Score(num_classes=1, threshold=0.5)

# %% [markdown]
# 용어 그대로라면 class가 2개인 binary classification이니까 num_class = 2로 설정하는 게 맞습니다.
#
# 하지만 tensorflow 내부에서 num_classes를 2로 설정하면 output layer의 node를 2개로 간주하면서 model train할 때 tensor 간의 shape이 맞지 않는 문제가 생깁니다.
#
# 그래서 binary classification에서만 예외적으로 num_classes를 1로 설정하면 됩니다.

# %%
def f1score_model():
    model = Sequential()
    # 2d_array (25000, 200)
    model.add(Embedding(max_features, embedding_dims, input_length=max_len))
    # 3d_array (25000, 200, 50)
    model.add(SimpleRNN(32, return_sequences = True)) # RNN의 output이 3d array가 됩니다.
    # 3d_array
    model.add(SimpleRNN(64))
    # 2d_array
    model.add(Dense(1, activation='sigmoid'))
    # 1d_array

    
    model.compile(optimizer = 'adam', metrics=['accuracy', precision, recall, f1score], loss = 'binary_crossentropy')

    return model

# %%
model_f = f1score_model()

# %%
history = model_f.fit(x_train, y_train, validation_split=0.2, epochs=5, batch_size=512)
# Out:
# Epoch 1/5
# 40/40 [==============================] - 21s 442ms/step - loss: 0.6762 - accuracy: 0.5580 - precision: 0.5556 - recall: 0.5839 - f1_score: 0.5693 - val_loss: 0.4476 - val_accuracy: 0.7970 - val_precision: 0.7595 - val_recall: 0.8619 - val_f1_score: 0.8074
# Epoch 2/5
# 40/40 [==============================] - 14s 363ms/step - loss: 0.3277 - accuracy: 0.8637 - precision: 0.8591 - recall: 0.8753 - f1_score: 0.8668 - val_loss: 0.3675 - val_accuracy: 0.8666 - val_precision: 0.8460 - val_recall: 0.8923 - val_f1_score: 0.8685
# Epoch 3/5
# 40/40 [==============================] - 13s 329ms/step - loss: 0.1529 - accuracy: 0.9475 - precision: 0.9480 - recall: 0.9459 - f1_score: 0.9470 - val_loss: 0.3741 - val_accuracy: 0.8558 - val_precision: 0.9130 - val_recall: 0.7825 - val_f1_score: 0.8427
# Epoch 4/5
# 40/40 [==============================] - 16s 391ms/step - loss: 0.0814 - accuracy: 0.9763 - precision: 0.9788 - recall: 0.9735 - f1_score: 0.9761 - val_loss: 0.3917 - val_accuracy: 0.8442 - val_precision: 0.8556 - val_recall: 0.8234 - val_f1_score: 0.8392
# Epoch 5/5
# 40/40 [==============================] - 13s 323ms/step - loss: 0.0509 - accuracy: 0.9857 - precision: 0.9884 - recall: 0.9832 - f1_score: 0.9858 - val_loss: 0.5020 - val_accuracy: 0.8636 - val_precision: 0.8648 - val_recall: 0.8578 - val_f1_score: 0.8613

# %% [markdown]
# precision과 recall의 조화평균(2ab/(a+b))를 구하면 f1_score가 나오는 것을 확인할 수 있습니다.

# %% [markdown]
# ## 2) custom metrics

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def f1score_model():
    model = Sequential()
    # 2d_array (25000, 200)
    model.add(Embedding(max_features, embedding_dims, input_length=max_len))
    # 3d_array (25000, 200, 50)
    model.add(SimpleRNN(32, return_sequences = True)) # RNN의 output이 3d array가 됩니다.
    # 3d_array
    model.add(SimpleRNN(64))
    # 2d_array
    model.add(Dense(1, activation='sigmoid'))
    # 1d_array

    
    model.compile(optimizer = 'adam', metrics=['accuracy', recall_m, precision_m, f1_m], loss = 'binary_crossentropy')

    return model

# %%
model_f = f1score_model()

# %%
history = model_f.fit(x_train, y_train, validation_split=0.2, epochs=5, batch_size=512)
# Out:
# Epoch 1/5
# 40/40 [==============================] - 15s 304ms/step - loss: 0.6945 - accuracy: 0.5256 - recall_m: 0.5427 - precision_m: 0.5308 - f1_m: 0.5288 - val_loss: 0.5472 - val_accuracy: 0.7290 - val_recall_m: 0.6475 - val_precision_m: 0.7670 - val_f1_m: 0.7018
# Epoch 2/5
# 40/40 [==============================] - 12s 292ms/step - loss: 0.4602 - accuracy: 0.7846 - recall_m: 0.7667 - precision_m: 0.8109 - f1_m: 0.7786 - val_loss: 0.3892 - val_accuracy: 0.8310 - val_recall_m: 0.9058 - val_precision_m: 0.7838 - val_f1_m: 0.8403
# Epoch 3/5
# 40/40 [==============================] - 13s 319ms/step - loss: 0.2421 - accuracy: 0.9084 - recall_m: 0.9226 - precision_m: 0.8987 - f1_m: 0.9099 - val_loss: 0.3825 - val_accuracy: 0.8394 - val_recall_m: 0.7793 - val_precision_m: 0.8812 - val_f1_m: 0.8269
# Epoch 4/5
# 40/40 [==============================] - 12s 308ms/step - loss: 0.1269 - accuracy: 0.9573 - recall_m: 0.9551 - precision_m: 0.9591 - f1_m: 0.9567 - val_loss: 0.4015 - val_accuracy: 0.8470 - val_recall_m: 0.8654 - val_precision_m: 0.8308 - val_f1_m: 0.8476
# Epoch 5/5
# 40/40 [==============================] - 13s 332ms/step - loss: 0.0600 - accuracy: 0.9846 - recall_m: 0.9855 - precision_m: 0.9834 - f1_m: 0.9844 - val_loss: 0.5367 - val_accuracy: 0.8356 - val_recall_m: 0.9094 - val_precision_m: 0.7895 - val_f1_m: 0.8450
