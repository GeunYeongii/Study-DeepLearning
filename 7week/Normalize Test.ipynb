# %% [markdown]
# # Normalize Test

# %%
from tensorflow.keras.datasets import fashion_mnist

(x,y), (x_test, y_test) = fashion_mnist.load_data()

# %%
from tensorflow.keras.utils import to_categorical

x = x.astype('float32')
x_test = x_test.astype('float32')

x = x.reshape(60000,-1)
x_test = x_test.reshape(10000,-1)
'''
x = x/255.
x_test = x/ 255.
'''
y = to_categorical(y, 10)
y_test = to_categorical(y_test, 10)

# %%
import numpy as np

np.max(x)
# Out:
# 255.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
def create_not_normalized_data_model():
    model = Sequential()
    model.add(Dense(64, input_shape=(784,), activation = 'relu'))
    model.add(Dense(128, activation = 'relu'))
    model.add(Dense(256, activation = 'relu'))
    model.add(Dense(10, activation = 'softmax',kernel_initializer = 'zeros'))
    
    model.compile(optimizer = 'sgd', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = create_not_normalized_data_model()

# %%
model.fit(x,y,epochs=5,validation_split=1/6, verbose=1)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 5s 3ms/step - loss: 69.0008 - accuracy: 0.1644 - val_loss: 1.8496 - val_accuracy: 0.2757
# Epoch 2/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7383 - accuracy: 0.2572 - val_loss: 1.5932 - val_accuracy: 0.3166
# Epoch 3/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 2.8237 - accuracy: 0.1424 - val_loss: 2.3053 - val_accuracy: 0.1022
# Epoch 4/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 2.2852 - accuracy: 0.1107 - val_loss: 2.3057 - val_accuracy: 0.1022
# Epoch 5/5
# 1563/1563 [==============================] - 3s 2ms/step - loss: 2.3034 - accuracy: 0.1020 - val_loss: 2.3032 - val_accuracy: 0.1023
